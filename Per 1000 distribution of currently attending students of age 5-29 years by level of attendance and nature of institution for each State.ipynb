# %%
import ghostscript

# %%
import pandas as pd
import camelot

# %%
tables=camelot.read_pdf(r"E:\Dataset2\f9a8b421-5538-eae8-8787-575c838e3404.pdf",pages="289,290,291,292,293,294,295,296,297",flavor='stream')

# %%
df1=tables[0].df

# %%
df1=df1.iloc[10:-5]

# %%
df1.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','U Sample Students']

# %%
df1.drop(["all","estd","Upper Primary-Recognised","Upper Primary-Unrecognised","U Sample Students"],axis=1,inplace=True)
# Out:
# C:\Users\sireesha.balagam\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df1=df1.melt(id_vars=[df1.columns[0],df1.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df1[["Level of Attendance","Nature of Institution"]]=df1[df1.columns[2]].str.split('-',expand=True)

# %%
df1
# Out:
#                 State Sample Students Nature of Institution  \
# 0      Andhra Pradesh              77            Recognised
# 1   Arunachal Pradesh              11            Recognised
# 2               Assam              30            Recognised
# 3               Bihar              99            Recognised
# 4        Chhattisgarh              12            Recognised
# ..                ...             ...                   ...
# 67         Chandigarh               7          Unrecognised
# 68  Dadra & N. Haveli               0          Unrecognised
# 69        Daman & Diu               2          Unrecognised
# 70        Lakshadweep               0          Unrecognised
# 71         Puducherry               6          Unrecognised
#
#    Distribution of Currently Attending Students Level of Attendance
# 0                                           946             Primary
# 1                                           325             Primary
# ...

# %%
df2=tables[0].df

# %%
df2=df2.iloc[10:-5]

# %%
df2.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','P Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','Sample Students']

# %%
df2.drop(["all","estd","Primary-Recognised","Primary-Unrecognised","P Sample Students"],axis=1,inplace=True)
# Out:
# C:\Users\sireesha.balagam\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df2=df2.melt(id_vars=[df2.columns[0],df2.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df2[["Level of Attendance","Nature of Institution"]]=df2[df2.columns[2]].str.split('-',expand=True)

# %%
df_rural_m=pd.concat([df1,df2])

# %%
df_rural_m.insert(1,"Residence Area","Rural")
df_rural_m.insert(2,"Gender","Male")

# %%
df_rural_m
# Out:
#                 State Residence Area Gender Sample Students  \
# 0      Andhra Pradesh          Rural   Male              77
# 1   Arunachal Pradesh          Rural   Male              11
# 2               Assam          Rural   Male              30
# 3               Bihar          Rural   Male              99
# 4        Chhattisgarh          Rural   Male              12
# ..                ...            ...    ...             ...
# 67         Chandigarh          Rural   Male               1
# 68  Dadra & N. Haveli          Rural   Male               0
# 69        Daman & Diu          Rural   Male               0
# 70        Lakshadweep          Rural   Male               0
# 71         Puducherry          Rural   Male               2
#
#    Nature of Institution Distribution of Currently Attending Students  \
# 0             Recognised                                          946
# 1             Recognised                                          325
# ...

# %%
df3=tables[1].df

# %%
df3=df3.iloc[10:-5]

# %%
df3.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','U Sample Students']

# %%
df3.drop(["all","estd","Upper Primary-Recognised","Upper Primary-Unrecognised","U Sample Students"],axis=1,inplace=True)
# Out:
# C:\Users\sireesha.balagam\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df3=df3.melt(id_vars=[df3.columns[0],df3.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df3[["Level of Attendance","Nature of Institution"]]=df3[df3.columns[2]].str.split('-',expand=True)

# %%
df4=tables[1].df

# %%
df4=df4.iloc[10:-5]

# %%
df4.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','P Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','Sample Students']

# %%
df4.drop(["all","estd","Primary-Recognised","Primary-Unrecognised","P Sample Students"],axis=1,inplace=True)

# %%
df4=df4.melt(id_vars=[df4.columns[0],df4.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df4[["Level of Attendance","Nature of Institution"]]=df4[df4.columns[2]].str.split('-',expand=True)

# %%
df_rural_f=pd.concat([df3,df4])

# %%
df_rural_f.insert(1,"Residence Area","Rural")
df_rural_f.insert(2,"Gender","Female")

# %%
df_rural_f
# Out:
#                 State Residence Area  Gender Sample Students  \
# 0      Andhra Pradesh          Rural  Female              52
# 1   Arunachal Pradesh          Rural  Female               4
# 2               Assam          Rural  Female              22
# 3               Bihar          Rural  Female              53
# 4        Chhattisgarh          Rural  Female              21
# ..                ...            ...     ...             ...
# 67         Chandigarh          Rural  Female               1
# 68  Dadra & N. Haveli          Rural  Female               0
# 69        Daman & Diu          Rural  Female               0
# 70        Lakshadweep          Rural  Female               0
# 71         Puducherry          Rural  Female               4
#
#    Nature of Institution Distribution of Currently Attending Students  \
# 0             Recognised                                          956
# 1             Recognised                                          541
# ...

# %%
df5=tables[2].df

# %%
df5=df5.iloc[10:-5]

# %%
df5.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','U Sample Students']

# %%
df5.drop(["all","estd","Upper Primary-Recognised","Upper Primary-Unrecognised","U Sample Students"],axis=1,inplace=True)
# Out:
# C:\Users\sireesha.balagam\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df5=df5.melt(id_vars=[df5.columns[0],df5.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df5[["Level of Attendance","Nature of Institution"]]=df5[df5.columns[2]].str.split('-',expand=True)

# %%
df6=tables[2].df

# %%
df6=df6.iloc[10:-5]

# %%
df6.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','P Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','Sample Students']

# %%
df6.drop(["all","estd","Primary-Recognised","Primary-Unrecognised","P Sample Students"],axis=1,inplace=True)

# %%
df6=df6.melt(id_vars=[df6.columns[0],df6.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df6[["Level of Attendance","Nature of Institution"]]=df6[df6.columns[2]].str.split('-',expand=True)

# %%
df_rural_p=pd.concat([df5,df6])

# %%
df_rural_p.insert(1,"Residence Area","Rural")
df_rural_p.insert(2,"Gender","Person")

# %%
df_rural_final=pd.concat([df_rural_m,df_rural_f,df_rural_p])

# %%
df_rural_final
# Out:
#                 State Residence Area  Gender Sample Students  \
# 0      Andhra Pradesh          Rural    Male              77
# 1   Arunachal Pradesh          Rural    Male              11
# 2               Assam          Rural    Male              30
# 3               Bihar          Rural    Male              99
# 4        Chhattisgarh          Rural    Male              12
# ..                ...            ...     ...             ...
# 67         Chandigarh          Rural  Person               2
# 68  Dadra & N. Haveli          Rural  Person               0
# 69        Daman & Diu          Rural  Person               0
# 70        Lakshadweep          Rural  Person               0
# 71         Puducherry          Rural  Person               6
#
#    Nature of Institution Distribution of Currently Attending Students  \
# 0             Recognised                                          946
# 1             Recognised                                          325
# ...

# %%
df7=tables[3].df

# %%
df7=df7.iloc[10:-5]

# %%
df7.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','U Sample Students']

# %%
df7.drop(["all","estd","Upper Primary-Recognised","Upper Primary-Unrecognised","U Sample Students"],axis=1,inplace=True)
# Out:
# C:\Users\sireesha.balagam\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df7=df7.melt(id_vars=[df7.columns[0],df7.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df7[["Level of Attendance","Nature of Institution"]]=df7[df7.columns[2]].str.split('-',expand=True)

# %%
df8=tables[3].df

# %%
df8=df8.iloc[10:-5]

# %%
df8.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','P Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','Sample Students']

# %%
df8.drop(["all","estd","Primary-Recognised","Primary-Unrecognised","P Sample Students"],axis=1,inplace=True)

# %%
df8=df8.melt(id_vars=[df8.columns[0],df8.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df8[["Level of Attendance","Nature of Institution"]]=df8[df8.columns[2]].str.split('-',expand=True)

# %%
df_urban_m=pd.concat([df7,df8])

# %%
df_urban_m.insert(1,"Residence Area","Urban")
df_urban_m.insert(2,"Gender","Male")

# %%
df_urban_m
# Out:
#                 State Residence Area Gender Sample Students  \
# 0      Andhra Pradesh          Urban   Male             153
# 1   Arunachal Pradesh          Urban   Male               7
# 2               Assam          Urban   Male              27
# 3               Bihar          Urban   Male             154
# 4        Chhattisgarh          Urban   Male              69
# ..                ...            ...    ...             ...
# 67         Chandigarh          Urban   Male               1
# 68  Dadra & N. Haveli          Urban   Male               2
# 69        Daman & Diu          Urban   Male               4
# 70        Lakshadweep          Urban   Male               0
# 71         Puducherry          Urban   Male               9
#
#    Nature of Institution Distribution of Currently Attending Students  \
# 0             Recognised                                          967
# 1             Recognised                                         1000
# ...

# %%
df9=tables[4].df

# %%
df9=df9.iloc[10:-5]

# %%
df9.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','U Sample Students']

# %%
df9.drop(["all","estd","Upper Primary-Recognised","Upper Primary-Unrecognised","U Sample Students"],axis=1,inplace=True)
# Out:
# C:\Users\sireesha.balagam\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df9=df9.melt(id_vars=[df9.columns[0],df9.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df9[["Level of Attendance","Nature of Institution"]]=df9[df9.columns[2]].str.split('-',expand=True)

# %%
df10=tables[4].df

# %%
df10=df10.iloc[10:-5]

# %%
df10.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','P Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','Sample Students']

# %%
df10.drop(["all","estd","Primary-Recognised","Primary-Unrecognised","P Sample Students"],axis=1,inplace=True)

# %%
df10=df10.melt(id_vars=[df10.columns[0],df10.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df10[["Level of Attendance","Nature of Institution"]]=df10[df10.columns[2]].str.split('-',expand=True)

# %%
df_urban_f=pd.concat([df9,df10])

# %%
df_urban_f.insert(1,"Residence Area","Urban")
df_urban_f.insert(2,"Gender","Female")

# %%
df_urban_f
# Out:
#                 State Residence Area  Gender Sample Students  \
# 0      Andhra Pradesh          Urban  Female             146
# 1   Arunachal Pradesh          Urban  Female               4
# 2               Assam          Urban  Female              24
# 3               Bihar          Urban  Female             126
# 4        Chhattisgarh          Urban  Female              46
# ..                ...            ...     ...             ...
# 67         Chandigarh          Urban  Female               4
# 68  Dadra & N. Haveli          Urban  Female               1
# 69        Daman & Diu          Urban  Female               0
# 70        Lakshadweep          Urban  Female               0
# 71         Puducherry          Urban  Female               5
#
#    Nature of Institution Distribution of Currently Attending Students  \
# 0             Recognised                                          941
# 1             Recognised                                         1000
# ...

# %%
df11=tables[5].df

# %%
df11=df11.iloc[10:-5]

# %%
df11.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','U Sample Students']

# %%
df11.drop(["all","estd","Upper Primary-Recognised","Upper Primary-Unrecognised","U Sample Students"],axis=1,inplace=True)
# Out:
# C:\Users\sireesha.balagam\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df11=df11.melt(id_vars=[df11.columns[0],df11.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df11[["Level of Attendance","Nature of Institution"]]=df11[df11.columns[2]].str.split('-',expand=True)

# %%
df12=tables[5].df

# %%
df12=df12.iloc[10:-5]

# %%
df12.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','P Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','Sample Students']

# %%
df12.drop(["all","estd","Primary-Recognised","Primary-Unrecognised","P Sample Students"],axis=1,inplace=True)

# %%
df12=df12.melt(id_vars=[df12.columns[0],df12.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df12[["Level of Attendance","Nature of Institution"]]=df12[df12.columns[2]].str.split('-',expand=True)

# %%
df_urban_p=pd.concat([df11,df12])

# %%
df_urban_p.insert(1,"Residence Area","Urban")
df_urban_p.insert(2,"Gender","Person")

# %%
df_urban_p
# Out:
#                 State Residence Area  Gender Sample Students  \
# 0      Andhra Pradesh          Urban  Person             299
# 1   Arunachal Pradesh          Urban  Person              11
# 2               Assam          Urban  Person              51
# 3               Bihar          Urban  Person             280
# 4        Chhattisgarh          Urban  Person             115
# ..                ...            ...     ...             ...
# 67         Chandigarh          Urban  Person               5
# 68  Dadra & N. Haveli          Urban  Person               3
# 69        Daman & Diu          Urban  Person               4
# 70        Lakshadweep          Urban  Person               0
# 71         Puducherry          Urban  Person              14
#
#    Nature of Institution Distribution of Currently Attending Students  \
# 0             Recognised                                          954
# 1             Recognised                                         1000
# ...

# %%
df_urban_final=pd.concat([df_urban_m,df_urban_f,df_urban_p])

# %%
df_urban_final
# Out:
#                 State Residence Area  Gender Sample Students  \
# 0      Andhra Pradesh          Urban    Male             153
# 1   Arunachal Pradesh          Urban    Male               7
# 2               Assam          Urban    Male              27
# 3               Bihar          Urban    Male             154
# 4        Chhattisgarh          Urban    Male              69
# ..                ...            ...     ...             ...
# 67         Chandigarh          Urban  Person               5
# 68  Dadra & N. Haveli          Urban  Person               3
# 69        Daman & Diu          Urban  Person               4
# 70        Lakshadweep          Urban  Person               0
# 71         Puducherry          Urban  Person              14
#
#    Nature of Institution Distribution of Currently Attending Students  \
# 0             Recognised                                          967
# 1             Recognised                                         1000
# ...

# %%
df13=tables[6].df

# %%
df13=df13.iloc[10:-3]

# %%
df13.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','U Sample Students']

# %%
df13.drop(["all","estd","Upper Primary-Recognised","Upper Primary-Unrecognised","U Sample Students"],axis=1,inplace=True)
# Out:
# C:\Users\sireesha.balagam\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df13=df13.melt(id_vars=[df13.columns[0],df13.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df13[["Level of Attendance","Nature of Institution"]]=df13[df13.columns[2]].str.split('-',expand=True)

# %%
df14=tables[6].df

# %%
df14=df14.iloc[10:-3]

# %%
df14.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','P Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','Sample Students']

# %%
df14.drop(["all","estd","Primary-Recognised","Primary-Unrecognised","P Sample Students"],axis=1,inplace=True)

# %%
df14=df14.melt(id_vars=[df14.columns[0],df14.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df14[["Level of Attendance","Nature of Institution"]]=df14[df14.columns[2]].str.split('-',expand=True)

# %%
df_total_m=pd.concat([df13,df14])

# %%
df_total_m.insert(1,"Residence Area","Total")
df_total_m.insert(2,"Gender","Male")

# %%
df_total_m
# Out:
#                 State Residence Area Gender Sample Students  \
# 0      Andhra Pradesh          Total   Male             230
# 1   Arunachal Pradesh          Total   Male              18
# 2               Assam          Total   Male              57
# 3               Bihar          Total   Male             253
# 4        Chhattisgarh          Total   Male              81
# ..                ...            ...    ...             ...
# 67         Chandigarh          Total   Male               2
# 68  Dadra & N. Haveli          Total   Male               2
# 69        Daman & Diu          Total   Male               4
# 70        Lakshadweep          Total   Male               0
# 71         Puducherry          Total   Male              11
#
#    Nature of Institution Distribution of Currently Attending Students  \
# 0             Recognised                                          956
# 1             Recognised                                          522
# ...

# %%
df15=tables[7].df

# %%
df15=df15.iloc[10:-5]

# %%
df15.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','U Sample Students']

# %%
df15.drop(["all","estd","Upper Primary-Recognised","Upper Primary-Unrecognised","U Sample Students"],axis=1,inplace=True)
# Out:
# C:\Users\sireesha.balagam\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df15=df15.melt(id_vars=[df15.columns[0],df15.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df15[["Level of Attendance","Nature of Institution"]]=df15[df15.columns[2]].str.split('-',expand=True)

# %%
df16=tables[7].df

# %%
df16=df16.iloc[10:-5]

# %%
df16.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','P Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','Sample Students']

# %%
df16.drop(["all","estd","Primary-Recognised","Primary-Unrecognised","P Sample Students"],axis=1,inplace=True)

# %%
df16=df16.melt(id_vars=[df16.columns[0],df16.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df16[["Level of Attendance","Nature of Institution"]]=df16[df16.columns[2]].str.split('-',expand=True)

# %%
df_total_f=pd.concat([df15,df16])

# %%
df_total_f.insert(1,"Residence Area","Total")
df_total_f.insert(2,"Gender","Female")

# %%
df_total_f
# Out:
#                 State Residence Area  Gender Sample Students  \
# 0      Andhra Pradesh          Total  Female             198
# 1   Arunachal Pradesh          Total  Female               8
# 2               Assam          Total  Female              46
# 3               Bihar          Total  Female             179
# 4        Chhattisgarh          Total  Female              67
# ..                ...            ...     ...             ...
# 67         Chandigarh          Total  Female               5
# 68  Dadra & N. Haveli          Total  Female               1
# 69        Daman & Diu          Total  Female               0
# 70        Lakshadweep          Total  Female               0
# 71         Puducherry          Total  Female               9
#
#    Nature of Institution Distribution of Currently Attending Students  \
# 0             Recognised                                          947
# 1             Recognised                                          678
# ...

# %%
df17=tables[8].df

# %%
df17=df17.iloc[10:-6]

# %%
df17.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','U Sample Students']

# %%
df17.drop(["all","estd","Upper Primary-Recognised","Upper Primary-Unrecognised","U Sample Students"],axis=1,inplace=True)
# Out:
# C:\Users\sireesha.balagam\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df17=df17.melt(id_vars=[df17.columns[0],df17.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df17[["Level of Attendance","Nature of Institution"]]=df17[df17.columns[2]].str.split('-',expand=True)

# %%
df18=tables[8].df

# %%
df18=df18.iloc[10:-6]

# %%
df18.columns=["State","Primary-Recognised",'Primary-Unrecognised','all','estd','P Sample Students','Upper Primary-Recognised','Upper Primary-Unrecognised','all','estd','Sample Students']

# %%
df18.drop(["all","estd","Primary-Recognised","Primary-Unrecognised","P Sample Students"],axis=1,inplace=True)

# %%
df18=df18.melt(id_vars=[df18.columns[0],df18.columns[-1]],var_name="Nature of Institution",value_name="Distribution of Currently Attending Students")

# %%
df18[["Level of Attendance","Nature of Institution"]]=df18[df18.columns[2]].str.split('-',expand=True)

# %%
df_total_p=pd.concat([df17,df18])

# %%
df_total_p.insert(1,"Residence Area","Total")
df_total_p.insert(2,"Gender","Person")

# %%
df_total_final=pd.concat([df_total_m,df_total_f,df_total_p])

# %%
df_total_final
# Out:
#                 State Residence Area  Gender Sample Students  \
# 0      Andhra Pradesh          Total    Male             230
# 1   Arunachal Pradesh          Total    Male              18
# 2               Assam          Total    Male              57
# 3               Bihar          Total    Male             253
# 4        Chhattisgarh          Total    Male              81
# ..                ...            ...     ...             ...
# 67         Chandigarh          Total  Person               7
# 68  Dadra & N. Haveli          Total  Person               3
# 69        Daman & Diu          Total  Person               4
# 70        Lakshadweep          Total  Person               0
# 71         Puducherry          Total  Person              20
#
#    Nature of Institution Distribution of Currently Attending Students  \
# 0             Recognised                                          956
# 1             Recognised                                          522
# ...

# %%
df_final=pd.concat([df_rural_final,df_urban_final,df_total_final])

# %%
df_final
# Out:
#                 State Residence Area  Gender Sample Students  \
# 0      Andhra Pradesh          Rural    Male              77
# 1   Arunachal Pradesh          Rural    Male              11
# 2               Assam          Rural    Male              30
# 3               Bihar          Rural    Male              99
# 4        Chhattisgarh          Rural    Male              12
# ..                ...            ...     ...             ...
# 67         Chandigarh          Total  Person               7
# 68  Dadra & N. Haveli          Total  Person               3
# 69        Daman & Diu          Total  Person               4
# 70        Lakshadweep          Total  Person               0
# 71         Puducherry          Total  Person              20
#
#    Nature of Institution Distribution of Currently Attending Students  \
# 0             Recognised                                          946
# 1             Recognised                                          325
# ...

# %%
df_final.insert(1,"Year","2014")

# %%
df_final=df_final[['State', 'Year', 'Residence Area', 'Gender', 'Level of Attendance', 
       'Nature of Institution', 'Distribution of Currently Attending Students','Sample Students']]

# %%
df_final
# Out:
#                 State  Year Residence Area  Gender Level of Attendance  \
# 0      Andhra Pradesh  2014          Rural    Male             Primary
# 1   Arunachal Pradesh  2014          Rural    Male             Primary
# 2               Assam  2014          Rural    Male             Primary
# 3               Bihar  2014          Rural    Male             Primary
# 4        Chhattisgarh  2014          Rural    Male             Primary
# ..                ...   ...            ...     ...                 ...
# 67         Chandigarh  2014          Total  Person       Upper Primary
# 68  Dadra & N. Haveli  2014          Total  Person       Upper Primary
# 69        Daman & Diu  2014          Total  Person       Upper Primary
# 70        Lakshadweep  2014          Total  Person       Upper Primary
# 71         Puducherry  2014          Total  Person       Upper Primary
#
#    Nature of Institution Distribution of Currently Attending Students  \
# ...

# %%
df_final[df_final.columns[0]]=df_final[df_final.columns[0]].str.replace("A & N Islands","Andaman & Nicobar Islands")
df_final[df_final.columns[0]]=df_final[df_final.columns[0]].str.replace("Dadra & N. Haveli","Dadra & Nagar Haveli")
# Out:
# C:\Users\SIREES~1.BAL\AppData\Local\Temp/ipykernel_43032/4213881610.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_final[df_final.columns[0]]=df_final[df_final.columns[0]].str.replace("Dadra & N. Haveli","Dadra & Nagar Haveli")

# %%
df_final
# Out:
#                    State  Year Residence Area  Gender Level of Attendance  \
# 0         Andhra Pradesh  2014          Rural    Male             Primary
# 1      Arunachal Pradesh  2014          Rural    Male             Primary
# 2                  Assam  2014          Rural    Male             Primary
# 3                  Bihar  2014          Rural    Male             Primary
# 4           Chhattisgarh  2014          Rural    Male             Primary
# ..                   ...   ...            ...     ...                 ...
# 67            Chandigarh  2014          Total  Person       Upper Primary
# 68  Dadra & Nagar Haveli  2014          Total  Person       Upper Primary
# 69           Daman & Diu  2014          Total  Person       Upper Primary
# 70           Lakshadweep  2014          Total  Person       Upper Primary
# 71            Puducherry  2014          Total  Person       Upper Primary
#
#    Nature of Institution Distribution of Currently Attending Students  \
# ...

# %%
df_final.to_excel("NSS_71_EDU_Table_17_18_07_2022.xlsx",index=False)
